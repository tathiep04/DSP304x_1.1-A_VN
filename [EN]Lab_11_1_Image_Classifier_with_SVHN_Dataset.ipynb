# %% [markdown]
# # Capstone Project
# ## Image classifier for the SVHN dataset
# ### Instructions
#
# In this notebook, you will create a neural network that classifies real-world images digits. You will use concepts from throughout this course in building, training, testing, validating and saving your Tensorflow classifier model.
#
# This project is peer-assessed. Within this notebook you will find instructions in each section for how to complete the project. Pay close attention to the instructions as the peer review will be carried out according to a grading rubric that checks key parts of the project instructions. Feel free to add extra cells into the notebook as required.
#
# ### How to submit
#
# When you have completed the Capstone project notebook, you will submit a pdf of the notebook for peer review. First ensure that the notebook has been fully executed from beginning to end, and all of the cell outputs are visible. This is important, as the grading rubric depends on the reviewer being able to view the outputs of your notebook. Save the notebook as a pdf (you could download the notebook with File -> Download .ipynb, open the notebook locally, and then File -> Download as -> PDF via LaTeX), and then submit this pdf for review.
#
# ### Let's get started!
#
# We'll start by running some imports, and loading the dataset. For this project you are free to make further imports throughout the notebook as you wish.

# %%
import tensorflow as tf
from scipy.io import loadmat
import numpy as np
import pandas as pd

# %% [markdown]
# For the capstone project, you will use the [SVHN dataset](http://ufldl.stanford.edu/housenumbers/). This is an image dataset of over 600,000 digit images in all, and is a harder dataset than MNIST as the numbers appear in the context of natural scene images. SVHN is obtained from house numbers in Google Street View images.
#
# * Y. Netzer, T. Wang, A. Coates, A. Bissacco, B. Wu and A. Y. Ng. "Reading Digits in Natural Images with Unsupervised Feature Learning". NIPS Workshop on Deep Learning and Unsupervised Feature Learning, 2011.
#
# The train and test datasets required for this project can be downloaded from [here](http://ufldl.stanford.edu/housenumbers/train.tar.gz) and [here](http://ufldl.stanford.edu/housenumbers/test.tar.gz). Once unzipped, you will have two files: `train_32x32.mat` and `test_32x32.mat`. You should store these files in Drive for use in this Colab notebook.
#
# Your goal is to develop an end-to-end workflow for building, training, validating, evaluating and saving a neural network that classifies a real-world image into one of ten classes.

# %%
# Run this cell to connect to your Drive folder

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# Load the dataset from your Drive folder

train = loadmat('/content/gdrive/My Drive/Datasets/train_32x32.mat')
test = loadmat('/content/gdrive/My Drive/Datasets/test_32x32.mat')

# %% [markdown]
# Both `train` and `test` are dictionaries with keys `X` and `y` for the input images and labels respectively.

# %% [markdown]
# ## 1. Inspect and preprocess the dataset
# * Extract the training and testing images and labels separately from the train and test dictionaries loaded for you.
# * Select a random sample of images and corresponding labels from the dataset (at least 10), and display them in a figure.
# * Convert the training and test images to grayscale by taking the average across all colour channels for each pixel. _Hint: retain the channel dimension, which will now have size 1._
# * Select a random sample of the grayscale images and corresponding labels from the dataset (at least 10), and display them in a figure.

# %%
##Preprocessing

from sklearn.preprocessing import OneHotEncoder

train_x = np.transpose(train['X'], (3,0,1,2)) / 255.
test_x = np.transpose(test['X'], (3,0,1,2)) / 255.
 
encoder = OneHotEncoder(sparse=False)

train_y = encoder.fit_transform(train['y'] % 10)
test_y = encoder.fit_transform(test['y'] % 10)

# %%
#Show random images
import random
import matplotlib.pyplot as plt

def random_imgs(x, y):
    num_samples = x.shape[0] 
    indexs = random.sample(range(0, num_samples + 1), 15)
    fig, axs = plt.subplots(nrows = 3, ncols = 5, figsize=(10,10))

    for idx, ax in zip(indexs, axs.flatten()):
        #usual case
        if(x[idx].shape == (32,32,3)):
            ax.imshow(x[idx])
        else: #graymap
            ax.imshow(x[idx,...,0],cmap='gray')
        ax.set_xlabel("label: " + str(np.argmax(y[idx])))

# %%
random_imgs(train_x, train_y)

# %%
#Take mean and reshape

#Weighted average
def rgb2gray(img):
        return np.dot(img, [0.2989, 0.5870, 0.1140])[...,np.newaxis]
    
train_x_gray = rgb2gray(train_x).astype(np.float32)
test_x_gray = rgb2gray(test_x).astype(np.float32)

# %%
random_imgs(train_x_gray,  train_y)

# %% [markdown]
# ## 2. MLP neural network classifier
# * Build an MLP classifier model using the Sequential API. Your model should use only Flatten and Dense layers, with the final layer having a 10-way softmax output.
# * You should design and build the model yourself. Feel free to experiment with different MLP architectures. _Hint: to achieve a reasonable accuracy you won't need to use more than 4 or 5 layers._
# * Print out the model summary (using the summary() method)
# * Compile and train the model (we recommend a maximum of 30 epochs), making use of both training and validation sets during the training run.
# * Your model should track at least one appropriate metric, and use at least two callbacks during training, one of which should be a ModelCheckpoint callback.
# * As a guide, you should aim to achieve a final categorical cross entropy training loss of less than 1.0 (the validation loss might be higher).
# * Plot the learning curves for loss vs epoch and accuracy vs epoch for both training and validation sets.
# * Compute and display the loss and accuracy of the trained model on the test set.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.regularizers import l1_l2

def get_mlp_model(input_shape):
    
    return Sequential([
        Flatten(name='flatten_1', input_shape = input_shape),
        Dense(128, activation = 'relu',name='dense_1'),
        Dense(128, activation='relu',name='dense_2'),
        Dense(128, activation='relu', name='dense_3'),
        Dense(128, activation='relu', name='dense_4'),
        Dense(64, activation='relu', name='dense_5'),
        Dense(10, activation='softmax', name='output')
    ])

# %%
def get_test_results(model):
    test_loss, test_accuracy = model.evaluate(test_x_gray, test_y, verbose = False)
    print(f"Test accuracy is {test_accuracy}")
    print(f"Test loss is {test_loss}")

# %%
def plot_models(history):
    
    
    fig, axs = plt.subplots(nrows = 2, ncols = 1, figsize=(10,10))
    axs[0].plot(history['val_loss'], label = 'validation loss', color = 'orange')
    axs[0].plot(history['loss'], label = 'training loss', color = 'blue')
    axs[0].set_ylabel('val loss')
    axs[0].set_xlabel('epoch')
    axs[0].legend()
    axs[1].plot(history['val_accuracy'], label = 'validation accuracy',color = 'orange')
    axs[1].plot(history['accuracy'], label = 'training accuracy',color = 'blue')
    axs[1].set_ylabel('val accuracy')
    axs[1].legend()
    axs[1].set_xlabel('epoch')

# %%
shape = train_x_gray[0].shape
model = get_mlp_model(shape)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               131200
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                8256
# _________________________________________________________________
# output (Dense)               (None, 10)                650
# =================================================================
# Total params: 189,642
# Trainable params: 189,642
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

def get_callbacks(model_type):
    
    early_stop = EarlyStopping(monitor = 'val_loss', patience = 10, verbose = 1)
    plateau = ReduceLROnPlateau(monitor='val_loss', patience = 10, factor = 0.2)
    
    checkp_path = 'model-' + model_type + '/checkpoint-epoch: {epoch:02d}'
    checkp = ModelCheckpoint(filepath=checkp_path, monitor='val_accuracy',save_weights_only=True,
                                save_best_only = True, verbose = 1)
    
    return early_stop, plateau, checkp

# %%
model.compile(
    optimizer = 'sgd',
    loss = 'categorical_crossentropy',
    metrics = ['accuracy']
)

# %%
early_stop, plateau, checkp = get_callbacks('mlp')
history_mlp= model.fit(train_x_gray, train_y, epochs = 30, callbacks= [early_stop, plateau, checkp], validation_split=0.15, verbose = 2)
# Out:
# Epoch 1/30
# 1946/1946 - 10s - loss: 2.1714 - accuracy: 0.2136 - val_loss: 1.9842 - val_accuracy: 0.3082
#
# Epoch 00001: val_accuracy improved from -inf to 0.30822, saving model to model-mlp/checkpoint-epoch: 01
# Epoch 2/30
# 1946/1946 - 7s - loss: 1.7768 - accuracy: 0.3886 - val_loss: 2.1913 - val_accuracy: 0.3146
#
# Epoch 00002: val_accuracy improved from 0.30822 to 0.31459, saving model to model-mlp/checkpoint-epoch: 02
# Epoch 3/30
# 1946/1946 - 7s - loss: 1.4449 - accuracy: 0.5209 - val_loss: 1.3044 - val_accuracy: 0.5783
#
# Epoch 00003: val_accuracy improved from 0.31459 to 0.57831, saving model to model-mlp/checkpoint-epoch: 03
# Epoch 4/30
# 1946/1946 - 6s - loss: 1.2367 - accuracy: 0.6027 - val_loss: 1.2254 - val_accuracy: 0.5984
#
# Epoch 00004: val_accuracy improved from 0.57831 to 0.59842, saving model to model-mlp/checkpoint-epoch: 04
# Epoch 5/30
# 1946/1946 - 7s - loss: 1.1116 - accuracy: 0.6477 - val_loss: 1.0579 - val_accuracy: 0.6763
#
# Epoch 00005: val_accuracy improved from 0.59842 to 0.67631, saving model to model-mlp/checkpoint-epoch: 05
# Epoch 6/30
# 1946/1946 - 7s - loss: 1.0256 - accuracy: 0.6772 - val_loss: 1.0542 - val_accuracy: 0.6710
#
# Epoch 00006: val_accuracy did not improve from 0.67631
# Epoch 7/30
# 1946/1946 - 7s - loss: 0.9600 - accuracy: 0.7005 - val_loss: 0.9347 - val_accuracy: 0.7039
#
# Epoch 00007: val_accuracy improved from 0.67631 to 0.70389, saving model to model-mlp/checkpoint-epoch: 07
# Epoch 8/30
# 1946/1946 - 7s - loss: 0.9115 - accuracy: 0.7145 - val_loss: 0.8669 - val_accuracy: 0.7245
#
# Epoch 00008: val_accuracy improved from 0.70389 to 0.72445, saving model to model-mlp/checkpoint-epoch: 08
# Epoch 9/30
# 1946/1946 - 7s - loss: 0.8667 - accuracy: 0.7271 - val_loss: 0.9369 - val_accuracy: 0.7114
#
# Epoch 00009: val_accuracy did not improve from 0.72445
# Epoch 10/30
# 1946/1946 - 7s - loss: 0.8319 - accuracy: 0.7403 - val_loss: 0.8712 - val_accuracy: 0.7315
#
# Epoch 00010: val_accuracy improved from 0.72445 to 0.73146, saving model to model-mlp/checkpoint-epoch: 10
# Epoch 11/30
# 1946/1946 - 7s - loss: 0.8042 - accuracy: 0.7489 - val_loss: 0.8418 - val_accuracy: 0.7414
#
# Epoch 00011: val_accuracy improved from 0.73146 to 0.74138, saving model to model-mlp/checkpoint-epoch: 11
# Epoch 12/30
# 1946/1946 - 6s - loss: 0.7764 - accuracy: 0.7562 - val_loss: 0.8097 - val_accuracy: 0.7465
#
# Epoch 00012: val_accuracy improved from 0.74138 to 0.74647, saving model to model-mlp/checkpoint-epoch: 12
# Epoch 13/30
# 1946/1946 - 6s - loss: 0.7495 - accuracy: 0.7671 - val_loss: 0.8084 - val_accuracy: 0.7477
#
# Epoch 00013: val_accuracy improved from 0.74647 to 0.74766, saving model to model-mlp/checkpoint-epoch: 13
# Epoch 14/30
# 1946/1946 - 7s - loss: 0.7294 - accuracy: 0.7715 - val_loss: 0.7686 - val_accuracy: 0.7608
#
# Epoch 00014: val_accuracy improved from 0.74766 to 0.76076, saving model to model-mlp/checkpoint-epoch: 14
# Epoch 15/30
# 1946/1946 - 7s - loss: 0.7076 - accuracy: 0.7797 - val_loss: 0.7491 - val_accuracy: 0.7624
#
# Epoch 00015: val_accuracy improved from 0.76076 to 0.76240, saving model to model-mlp/checkpoint-epoch: 15
# Epoch 16/30
# 1946/1946 - 6s - loss: 0.6907 - accuracy: 0.7830 - val_loss: 0.7128 - val_accuracy: 0.7792
#
# Epoch 00016: val_accuracy improved from 0.76240 to 0.77923, saving model to model-mlp/checkpoint-epoch: 16
# Epoch 17/30
# 1946/1946 - 7s - loss: 0.6732 - accuracy: 0.7902 - val_loss: 0.7001 - val_accuracy: 0.7822
#
# Epoch 00017: val_accuracy improved from 0.77923 to 0.78224, saving model to model-mlp/checkpoint-epoch: 17
# Epoch 18/30
# 1946/1946 - 7s - loss: 0.6547 - accuracy: 0.7938 - val_loss: 0.7606 - val_accuracy: 0.7594
#
# Epoch 00018: val_accuracy did not improve from 0.78224
# Epoch 19/30
# 1946/1946 - 7s - loss: 0.6399 - accuracy: 0.8012 - val_loss: 0.7119 - val_accuracy: 0.7831
#
# Epoch 00019: val_accuracy improved from 0.78224 to 0.78315, saving model to model-mlp/checkpoint-epoch: 19
# Epoch 20/30
# 1946/1946 - 7s - loss: 0.6266 - accuracy: 0.8038 - val_loss: 0.6857 - val_accuracy: 0.7885
#
# Epoch 00020: val_accuracy improved from 0.78315 to 0.78852, saving model to model-mlp/checkpoint-epoch: 20
# Epoch 21/30
# 1946/1946 - 7s - loss: 0.6115 - accuracy: 0.8076 - val_loss: 0.6629 - val_accuracy: 0.7958
#
# Epoch 00021: val_accuracy improved from 0.78852 to 0.79580, saving model to model-mlp/checkpoint-epoch: 21
# Epoch 22/30
# 1946/1946 - 7s - loss: 0.6011 - accuracy: 0.8117 - val_loss: 0.6921 - val_accuracy: 0.7855
#
# Epoch 00022: val_accuracy did not improve from 0.79580
# Epoch 23/30
# 1946/1946 - 6s - loss: 0.5901 - accuracy: 0.8147 - val_loss: 0.6545 - val_accuracy: 0.7995
#
# Epoch 00023: val_accuracy improved from 0.79580 to 0.79953, saving model to model-mlp/checkpoint-epoch: 23
# Epoch 24/30
# 1946/1946 - 7s - loss: 0.5766 - accuracy: 0.8198 - val_loss: 0.6246 - val_accuracy: 0.8093
#
# Epoch 00024: val_accuracy improved from 0.79953 to 0.80926, saving model to model-mlp/checkpoint-epoch: 24
# Epoch 25/30
# 1946/1946 - 6s - loss: 0.5667 - accuracy: 0.8215 - val_loss: 0.6277 - val_accuracy: 0.8082
#
# Epoch 00025: val_accuracy did not improve from 0.80926
# Epoch 26/30
# 1946/1946 - 6s - loss: 0.5564 - accuracy: 0.8252 - val_loss: 0.6546 - val_accuracy: 0.7991
#
# Epoch 00026: val_accuracy did not improve from 0.80926
# Epoch 27/30
# 1946/1946 - 6s - loss: 0.5468 - accuracy: 0.8277 - val_loss: 0.6351 - val_accuracy: 0.8060
#
# Epoch 00027: val_accuracy did not improve from 0.80926
# Epoch 28/30
# 1946/1946 - 7s - loss: 0.5361 - accuracy: 0.8308 - val_loss: 0.6643 - val_accuracy: 0.7964
#
# Epoch 00028: val_accuracy did not improve from 0.80926
# Epoch 29/30
# 1946/1946 - 7s - loss: 0.5289 - accuracy: 0.8335 - val_loss: 0.6262 - val_accuracy: 0.8074
#
# Epoch 00029: val_accuracy did not improve from 0.80926
# Epoch 30/30
# 1946/1946 - 7s - loss: 0.5187 - accuracy: 0.8383 - val_loss: 0.5946 - val_accuracy: 0.8184
#
# Epoch 00030: val_accuracy improved from 0.80926 to 0.81836, saving model to model-mlp/checkpoint-epoch: 30

# %%
get_test_results(model)
# Out:
# Test accuracy is 0.799362301826477
# Test loss is 0.6844244003295898

# %%
plot_models(history_mlp.history)

# %% [markdown]
# ## 3. CNN neural network classifier
# * Build a CNN classifier model using the Sequential API. Your model should use the Conv2D, MaxPool2D, BatchNormalization, Flatten, Dense and Dropout layers. The final layer should again have a 10-way softmax output.
# * You should design and build the model yourself. Feel free to experiment with different CNN architectures. _Hint: to achieve a reasonable accuracy you won't need to use more than 2 or 3 convolutional layers and 2 fully connected layers.)_
# * The CNN model should use fewer trainable parameters than your MLP model.
# * Compile and train the model (we recommend a maximum of 30 epochs), making use of both training and validation sets during the training run.
# * Your model should track at least one appropriate metric, and use at least two callbacks during training, one of which should be a ModelCheckpoint callback.
# * You should aim to beat the MLP model performance with fewer parameters!
# * Plot the learning curves for loss vs epoch and accuracy vs epoch for both training and validation sets.
# * Compute and display the loss and accuracy of the trained model on the test set.

# %%
from tensorflow.keras.layers import Conv2D, MaxPool2D, BatchNormalization, Dropout

def get_cnn_model(input_shape, keep_prob):
    
    return Sequential([
        Conv2D(32, kernel_size = 3, 
               input_shape=input_shape, name='conv_1'
               ,activation='relu'),
        Conv2D(16, kernel_size = 3 , name='conv_2', activation='relu'),
        MaxPool2D(pool_size=2, name='pool_1'),
        Flatten(name='flatten_1'),
        Dense(32, activation='relu', name = 'dense_1'),
        Dropout(keep_prob),
        Dense(32, activation='relu', name = 'dense_3'),
        BatchNormalization(),
        Dense(10, activation='softmax',name='output')
    ])

# %%
shape = train_x_gray[0].shape
model = get_cnn_model(shape, 0.3)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv_1 (Conv2D)              (None, 30, 30, 32)        320
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 28, 28, 16)        4624
# _________________________________________________________________
# pool_1 (MaxPooling2D)        (None, 14, 14, 16)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3136)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                100384
# _________________________________________________________________
# dropout (Dropout)            (None, 32)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                1056
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32)                128
# _________________________________________________________________
# output (Dense)               (None, 10)                330
# =================================================================
# Total params: 106,842
# Trainable params: 106,778
# Non-trainable params: 64
# _________________________________________________________________

# %%
model.compile(
    optimizer = 'adam',
    loss = 'categorical_crossentropy',
    metrics = ['accuracy']
)

# %%
early_stop, plateau, checkp = get_callbacks('cnn')
history_cnn = model.fit(train_x_gray, train_y, epochs = 20, callbacks= [early_stop, plateau, checkp], validation_split=0.15)
# Out:
# Epoch 1/20
# 1946/1946 [==============================] - 45s 9ms/step - loss: 1.2974 - accuracy: 0.5676 - val_loss: 0.7461 - val_accuracy: 0.7844
#
# Epoch 00001: val_accuracy improved from -inf to 0.78442, saving model to model-cnn/checkpoint-epoch: 01
# Epoch 2/20
# 1946/1946 [==============================] - 17s 9ms/step - loss: 0.9256 - accuracy: 0.6976 - val_loss: 0.6648 - val_accuracy: 0.8016
#
# Epoch 00002: val_accuracy improved from 0.78442 to 0.80162, saving model to model-cnn/checkpoint-epoch: 02
# Epoch 3/20
# 1946/1946 [==============================] - 17s 9ms/step - loss: 0.8614 - accuracy: 0.7219 - val_loss: 0.7005 - val_accuracy: 0.7815
#
# Epoch 00003: val_accuracy did not improve from 0.80162
# Epoch 4/20
# 1946/1946 [==============================] - 18s 9ms/step - loss: 0.8243 - accuracy: 0.7343 - val_loss: 0.6259 - val_accuracy: 0.8111
#
# Epoch 00004: val_accuracy improved from 0.80162 to 0.81108, saving model to model-cnn/checkpoint-epoch: 04
# Epoch 5/20
# 1946/1946 [==============================] - 17s 9ms/step - loss: 0.7778 - accuracy: 0.7519 - val_loss: 0.5954 - val_accuracy: 0.8171
#
# Epoch 00005: val_accuracy improved from 0.81108 to 0.81709, saving model to model-cnn/checkpoint-epoch: 05
# Epoch 6/20
# 1946/1946 [==============================] - 17s 8ms/step - loss: 0.7491 - accuracy: 0.7603 - val_loss: 0.5995 - val_accuracy: 0.8164
#
# Epoch 00006: val_accuracy did not improve from 0.81709
# Epoch 7/20
# 1946/1946 [==============================] - 16s 8ms/step - loss: 0.7230 - accuracy: 0.7688 - val_loss: 0.5292 - val_accuracy: 0.8418
#
# Epoch 00007: val_accuracy improved from 0.81709 to 0.84175, saving model to model-cnn/checkpoint-epoch: 07
# Epoch 8/20
# 1946/1946 [==============================] - 16s 8ms/step - loss: 0.7045 - accuracy: 0.7756 - val_loss: 0.5528 - val_accuracy: 0.8318
#
# Epoch 00008: val_accuracy did not improve from 0.84175
# Epoch 9/20
# 1946/1946 [==============================] - 17s 9ms/step - loss: 0.7004 - accuracy: 0.7759 - val_loss: 0.5346 - val_accuracy: 0.8348
#
# Epoch 00009: val_accuracy did not improve from 0.84175
# Epoch 10/20
# 1946/1946 [==============================] - 17s 8ms/step - loss: 0.6873 - accuracy: 0.7800 - val_loss: 0.5558 - val_accuracy: 0.8313
#
# Epoch 00010: val_accuracy did not improve from 0.84175
# Epoch 11/20
# 1946/1946 [==============================] - 16s 8ms/step - loss: 0.6741 - accuracy: 0.7852 - val_loss: 0.5290 - val_accuracy: 0.8381
#
# Epoch 00011: val_accuracy did not improve from 0.84175
# Epoch 12/20
# 1946/1946 [==============================] - 17s 8ms/step - loss: 0.6681 - accuracy: 0.7868 - val_loss: 0.5247 - val_accuracy: 0.8388
#
# Epoch 00012: val_accuracy did not improve from 0.84175
# Epoch 13/20
# 1946/1946 [==============================] - 17s 9ms/step - loss: 0.6595 - accuracy: 0.7900 - val_loss: 0.5275 - val_accuracy: 0.8383
#
# Epoch 00013: val_accuracy did not improve from 0.84175
# Epoch 14/20
# 1946/1946 [==============================] - 16s 8ms/step - loss: 0.6565 - accuracy: 0.7939 - val_loss: 0.5261 - val_accuracy: 0.8381
#
# Epoch 00014: val_accuracy did not improve from 0.84175
# Epoch 15/20
# 1946/1946 [==============================] - 16s 8ms/step - loss: 0.6529 - accuracy: 0.7928 - val_loss: 0.5242 - val_accuracy: 0.8405
#
# Epoch 00015: val_accuracy did not improve from 0.84175
# Epoch 16/20
# 1946/1946 [==============================] - 16s 8ms/step - loss: 0.6462 - accuracy: 0.7961 - val_loss: 0.5136 - val_accuracy: 0.8445
#
# Epoch 00016: val_accuracy improved from 0.84175 to 0.84448, saving model to model-cnn/checkpoint-epoch: 16
# Epoch 17/20
# 1946/1946 [==============================] - 16s 8ms/step - loss: 0.6472 - accuracy: 0.7956 - val_loss: 0.5245 - val_accuracy: 0.8419
#
# Epoch 00017: val_accuracy did not improve from 0.84448
# Epoch 18/20
# 1946/1946 [==============================] - 17s 9ms/step - loss: 0.6413 - accuracy: 0.7972 - val_loss: 0.5421 - val_accuracy: 0.8337
#
# Epoch 00018: val_accuracy did not improve from 0.84448
# Epoch 19/20
# 1946/1946 [==============================] - 17s 9ms/step - loss: 0.6310 - accuracy: 0.8012 - val_loss: 0.5256 - val_accuracy: 0.8396
#
# Epoch 00019: val_accuracy did not improve from 0.84448
# Epoch 20/20
# 1946/1946 [==============================] - 18s 9ms/step - loss: 0.6336 - accuracy: 0.8002 - val_loss: 0.5202 - val_accuracy: 0.8417
#
# Epoch 00020: val_accuracy did not improve from 0.84448

# %%
get_test_results(model)
# Out:
# Test accuracy is 0.8215657472610474
# Test loss is 0.5938655734062195

# %%
plot_models(history_cnn.history)

# %% [markdown]
# ## 4. Get model predictions
# * Load the best weights for the MLP and CNN models that you saved during the training run.
# * Randomly select 5 images and corresponding labels from the test set and display the images with their labels.
# * Alongside the image and label, show each model’s predictive distribution as a bar chart, and the final model prediction given by the label with maximum probability.

# %%
def get_best_model_mlp(model):
      checkp = tf.train.latest_checkpoint('model-mlp')
      model.compile(
          optimizer = 'adam',
          loss = 'categorical_crossentropy',
          metrics = ['accuracy']
      )
      model.load_weights(checkp)

      return model

def get_best_model_cnn(model):
      checkp = tf.train.latest_checkpoint('model-cnn')
      model.compile(
          optimizer = 'adam',
          loss = 'categorical_crossentropy',
          metrics = ['accuracy']
      )
      model.load_weights(checkp)

      return model
  
def random_img_from_model(model):
        num_samples = test_x.shape[0]
        indexs = random.sample(range(0, num_samples + 1), 6)

        fig, axs = plt.subplots(1,5, figsize = (8, 8))

        for idx, ax in zip(indexs, axs.flatten()):
              ax.imshow(test_x[idx])
              prediction = model.predict(test_x_gray[idx][np.newaxis, ...])
              ax.set_xlabel("prediction:" + str(np.argmax(prediction)))

# %%
model_mlp = get_best_model_mlp(get_mlp_model(train_x_gray[0].shape))
model_cnn = get_best_model_cnn(get_cnn_model(train_x_gray[0].shape, 0.3))

# %%
print("MLP Result: ")
get_test_results(model_mlp)

print('\n')
print('CNN Result: ')
get_test_results(model_cnn)
# Out:
# MLP Result:
# Test accuracy is 0.799362301826477
# Test loss is 0.6844244003295898
#
#
# CNN Result:
# Test accuracy is 0.817878007888794
# Test loss is 0.5971048474311829

# %%
random_img_from_model(model_mlp)
